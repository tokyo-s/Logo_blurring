# %% [markdown]
# ![image.png](attachment:4819c338-3a4e-40e9-9836-de790ef69b93.png)

# %%
l2 = ['a','b','c']

# %%
l2[-1:] = ['d','e']

# %%
x = 'winer' 'personal'

# %%
x = {'a':4}

# %%
del x['a']

# %%
x
# Out:
# {}

# %%
x = {'a':{'b':4}}

# %%
x
# Out:
# {'a': {'b': 4}}
